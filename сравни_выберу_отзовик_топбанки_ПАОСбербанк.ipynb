# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from requests.exceptions import ConnectionError
import time

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# =========================================== 
# SRAVNI.RU
# =========================================== 


for i in range(21, 85):
    df1 = pd.DataFrame()
    print(i, pd.Timestamp.now())
    url = f'https://www.sravni.ru/banki/sberbank-rossii/otzyvy?page=' + str(i)
    headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
                "Accept-Encoding": "*",
                "Connection": "keep-alive"
            }
    response = requests.get(url, headers=headers, verify=False)
    time.sleep(1)
    dom = bs(response.text, 'html.parser')
    
    links = dom.find_all('span', {'class', 'cPAIqy'})
    time.sleep(1)
    for link in links:
        res_link = link.find('a').get("href")
        p = f'https://www.sravni.ru' + str(res_link)
        rsp = requests.get( p, headers=headers, verify=False)
        time.sleep(0.3)
        dom2 = bs(rsp.text, 'html.parser') 
        
        txt = dom2.find('div', {'class': 'eCTrNq'}).getText().replace('\t', '').replace('\n', '')
        time.sleep(0.2)
        #if ("нет в наличии слитков" in str(txt.lower())) or ("нет слитков" in str(txt.lower())) or ("нет в наличии слитк" in str(txt.lower())) or ("нет слитк" in str(txt.lower())) or ("нет слиток" in str(txt.lower())) or ("слиток" in str(txt.lower())) or ("слитков" in str(txt.lower())) or ("золот" in str(txt.lower())) or (("драг" in str(txt.lower())) and ("метал" in str(txt.lower()))) or ("слитк" in str(txt.lower())) or ("купить" in str(txt.lower())) or ("приобре" in str(txt.lower())) or ("инвестици" in str(txt.lower())) or ("инвест" in str(txt.lower())) or ("инвести" in str(txt.lower())) or ("инвестиц" in str(txt.lower())) or ("нет" in str(txt.lower())) or ("в наличии" in str(txt.lower())) or (("качество" in str(txt.lower())) and ("обслуживан" in str(txt.lower()))) or ("метал" in str(txt.lower())) or ("драг" in str(txt.lower())):
        city = dom2.find('span', {'class': 'nXSPo'}).getText().replace('\t','').replace('\n','').split(',')[0]
        time.sleep(0.2)
        date = dom2.find('span', {'class': 'hgjOYK'}).getText()
        time.sleep(0.2)
        title = dom2.find('h1').getText().replace('\t', '').replace('\n', '')            
        time.sleep(0.2)
        new_row = {'Сайт': 'www.sravni.ru', 'Населенный пункт': city, 'Дата': date, 'Заголовок': title, 'Основной текст жалобы': txt}
        df1 = df1.append(new_row, ignore_index=True)
    df1.to_excel(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\сравни\sravni' + str(i) + '.xlsx', index=False)

# %%
df1

# %%
# =========================================== 
# ВЫБЕРУ
# =========================================== 


for i in range(1, 10):
    df2 = pd.DataFrame()
    print(i, pd.Timestamp.now())
    url = f'https://www.vbr.ru/banki/sberbank-rossii/otzivy/page/' + str(i)
    headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
                "Accept-Encoding": "*",
                "Connection": "keep-alive"
            }
    response = requests.get(url, headers=headers, verify=False)
    time.sleep(0.1)
    dom = bs(response.text, 'html.parser')
    links = dom.find_all('a', {'class', 'reviews-card-overlay'})
    time.sleep(0.1)
    for link in links:
        res_link = link.get("href")
        time.sleep(0.1)
        rsp = requests.get(res_link, headers=headers, verify=False)        
        time.sleep(0.3)
        dom2 = bs(rsp.text, 'html.parser') 
        txt = dom2.find('div', {'class': 'reviews-text'}).getText().replace('\t', '').replace('\n', '')
        time.sleep(0.1)
        #if ("нет в наличии слитков" in str(txt.lower())) or ("нет слитков" in str(txt.lower())) or ("нет в наличии слитк" in str(txt.lower())) or ("нет слитк" in str(txt.lower())) or ("нет слиток" in str(txt.lower())) or ("слиток" in str(txt.lower())) or ("слитков" in str(txt.lower())) or ("золот" in str(txt.lower())) or (("драг" in str(txt.lower())) and ("метал" in str(txt.lower()))) or ("слитк" in str(txt.lower())) or ("купить" in str(txt.lower())) or ("приобре" in str(txt.lower())) or ("инвестици" in str(txt.lower())) or ("инвест" in str(txt.lower())) or ("инвести" in str(txt.lower())) or ("инвестиц" in str(txt.lower())) or ("нет" in str(txt.lower())) or ("в наличии" in str(txt.lower())) or (("качество" in str(txt.lower())) and ("обслуживан" in str(txt.lower()))) or ("метал" in str(txt.lower())) or ("драг" in str(txt.lower())):
        inf = dom2.find('span', {'class': 'avatar-title-date'}).getText()
        time.sleep(0.1)
        city = inf.replace('\t','').replace('\n','').split(',')[0]
        time.sleep(0.1)
        date = inf.replace('\t','').replace('\n','').split(',')[1]
        time.sleep(0.1)
        title = dom2.find('div', {'class': 'avatar-title-text'}).getText().replace('\t', '').replace('\n', '')            
        new_row = {'Сайт': 'www.vbr.ru', 'Населенный пункт': city, 'Дата': date, 'Заголовок': title, 'Основной текст жалобы': txt}
        df2 = df2.append(new_row, ignore_index=True)
    df2.to_excel(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\vbr' + str(i) + '.xlsx', index=False)

# %%
# =========================================== 
# ОТЗОВИК
# =========================================== 
# df3 = pd.DataFrame()

for i in range(1, 6):
    print(i, pd.Timestamp.now())
    url = f'http://otzovik.com/reviews/sberbank_rossii/' + str(i) + '/?order=date_desc'
    headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
                "Accept-Encoding": "*",
                "Connection": "keep-alive"
            }
    response = requests.get(url, headers=headers)
    time.sleep(3)
    dom = bs(response.text, 'html.parser')
    break
#     time.sleep(3)
#     links = dom.find_all('a', {'class', 'review-title'})
#     time.sleep(3)
#     for link in links:
#         res_link = link.get("href")
#         path = 'https://otzovik.com' + res_link
#         rsp = requests.get(path, headers=headers, verify=False)
#         time.sleep(5)
#         dom2 = bs(rsp.text, 'html.parser') 
#         txt = dom2.find('div', {'class': 'review-body'}).getText().replace('\t', '').replace('\n', '')
#         time.sleep(3)
#         if ("нет в наличии слитков" in str(txt.lower())) or ("нет слитков" in str(txt.lower())) or ("нет в наличии слитк" in str(txt.lower())) or ("нет слитк" in str(txt.lower())) or ("нет слиток" in str(txt.lower())) or ("слиток" in str(txt.lower())) or ("слитков" in str(txt.lower())) or ("золот" in str(txt.lower())) or (("драг" in str(txt.lower())) and ("метал" in str(txt.lower()))) or ("слитк" in str(txt.lower())) or ("купить" in str(txt.lower())) or ("приобре" in str(txt.lower())) or ("инвестици" in str(txt.lower())) or ("инвест" in str(txt.lower())) or ("инвести" in str(txt.lower())) or ("инвестиц" in str(txt.lower())) or ("нет" in str(txt.lower())) or ("в наличии" in str(txt.lower())) or (("качество" in str(txt.lower())) and ("обслуживан" in str(txt.lower()))) or ("метал" in str(txt.lower())) or ("драг" in str(txt.lower())):
#             city = dom2.find('div', {'class': 'user-location'}).getText().replace('\t','').replace('\n','')
#             time.sleep(2)
#             date = dom2.find('span', {'class': 'tooltip-right'}).getText().replace('\t','').replace('\n','')
#             time.sleep(2)
#             title = dom2.find('h1').getText().replace('\t', '').replace('\n', '').replace('\t','')            
#             time.sleep(2)
#             new_row = {'Сайт': 'otzovik.com', 'Населенный пункт': city, 'Дата': date, 'Заголовок': title, 'Основной текст жалобы': txt}
#             df3 = df3.append(new_row, ignore_index=True)

# %%
# =========================================== 
# ТОПБАНКИ
# =========================================== 


for i in range(1, 20):
    df4 = pd.DataFrame()
    print(i, pd.Timestamp.now())
    url = f'https://topbanki.ru/banks/sbrf/page' + str(i)
    headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
                "Accept-Encoding": "*",
                "Connection": "keep-alive"
            }
    response = requests.get(url, headers=headers, verify=False)
    time.sleep(0.3)
    dom = bs(response.text, 'html.parser')
    
    blocks = dom.find_all('div', {'class', 'mb5'})
    
    for block in blocks[0:]:
        try:
            txt = block.find('p', {'class': 'text'}).getText().replace('\t', '').replace('\n', '')
            #if ("нет в наличии слитков" in str(txt.lower())) or ("нет слитков" in str(txt.lower())) or ("нет в наличии слитк" in str(txt.lower())) or ("нет слитк" in str(txt.lower())) or ("нет слиток" in str(txt.lower())) or ("слиток" in str(txt.lower())) or ("слитков" in str(txt.lower())) or ("золот" in str(txt.lower())) or (("драг" in str(txt.lower())) and ("метал" in str(txt.lower()))) or ("слитк" in str(txt.lower())) or ("купить" in str(txt.lower())) or ("приобре" in str(txt.lower())) or ("инвестици" in str(txt.lower())) or ("инвест" in str(txt.lower())) or ("инвести" in str(txt.lower())) or ("инвестиц" in str(txt.lower())) or ("нет" in str(txt.lower())) or ("в наличии" in str(txt.lower())) or (("качество" in str(txt.lower())) and ("обслуживан" in str(txt.lower()))) or ("метал" in str(txt.lower())) or ("драг" in str(txt.lower())):
            date = block.find('div', {'class': 'date'}).getText().replace('\t','').replace('\n','')
            title = block.find('div', {'class': 'name'}).getText().replace('\t', '').replace('\n', '').replace('\t','')
            new_row = {'Сайт': 'topbanki.ru', 'Населенный пункт': city, 'Дата': date, 'Заголовок': title, 'Основной текст жалобы': txt}
            df4 = df4.append(new_row, ignore_index=True)
            df4.to_excel(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\выберу\topbanki' + str(i) + '.xlsx', index=False)
    
        except:
            pass

# %%
# =========================================== 
# ПАО СБЕРБАНК
# =========================================== 




url = f'https://sber-address.ru/complaints.html'
headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
            "Accept-Encoding": "*",
            "Connection": "keep-alive"
        }
response = requests.get(url, headers=headers, verify=False)
dom = bs(response.text, 'html.parser')

blocks = dom.find_all('div', {'class', 'rewiews_list'})
r = 1
for block in blocks:
    df5 = pd.DataFrame()
    print(r)
    txt = block.find('div', {'class': 'one_ot_text'}).find('p').getText().replace('\t', '').replace('\n', '')
    #if ("нет в наличии слитков" in str(txt.lower())) or ("нет слитков" in str(txt.lower())) or ("нет в наличии слитк" in str(txt.lower())) or ("нет слитк" in str(txt.lower())) or ("нет слиток" in str(txt.lower())) or ("слиток" in str(txt.lower())) or ("слитков" in str(txt.lower())) or ("золот" in str(txt.lower())) or (("драг" in str(txt.lower())) and ("метал" in str(txt.lower()))) or ("слитк" in str(txt.lower())) or ("купить" in str(txt.lower())) or ("приобре" in str(txt.lower())) or ("инвестици" in str(txt.lower())) or ("инвест" in str(txt.lower())) or ("инвести" in str(txt.lower())) or ("инвестиц" in str(txt.lower())) or ("нет" in str(txt.lower())) or ("в наличии" in str(txt.lower())) or (("качество" in str(txt.lower())) and ("обслуживан" in str(txt.lower()))) or ("метал" in str(txt.lower())) or ("драг" in str(txt.lower())):
    date = block.find('p', {'class': 'com_date'}).getText().replace('\t','').replace('\n','')
    title = block.find('h3').getText().replace('\t', '').replace('\n', '').replace('\t','')       
    new_row = {'Сайт': 'sber-address.ru', 'Населенный пункт': city, 'Дата': date, 'Заголовок': title, 'Основной текст жалобы': txt}
    df5 = df5.append(new_row, ignore_index=True)
    df5.to_excel(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\sberadr\sber-address' + str(r) + '.xlsx', index=False)
    r += 1

# %%
# =========================================== 
# OTZYV
# =========================================== 


for i in range(1, 25):
    df6 = pd.DataFrame()
    print(i, pd.Timestamp.now())
    url = f'https://www.otzyvru.com/sberbank-rossii?page=' + str(i)
    headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
                "Accept-Encoding": "*",
                "Connection": "keep-alive"
            }
    response = requests.get(url, headers=headers, verify=False)
    dom = bs(response.text, 'html.parser')
    
    links = dom.find_all('h2')    
    for link in links:    
        try: 
            res_link = link.find('a').get("href")
        except:
            pass
        rsp = requests.get(res_link, headers=headers, verify=False)
        dom2 = bs(rsp.text, 'html.parser')  
        txt = dom2.find('span', {'class': 'description'}).getText().replace('\t', '').replace('\n', '')
        #if ("нет в наличии слитков" in str(txt.lower())) or ("нет слитков" in str(txt.lower())) or ("нет в наличии слитк" in str(txt.lower())) or ("нет слитк" in str(txt.lower())) or ("нет слиток" in str(txt.lower())) or ("слиток" in str(txt.lower())) or ("слитков" in str(txt.lower())) or ("золот" in str(txt.lower())) or (("драг" in str(txt.lower())) and ("метал" in str(txt.lower()))) or ("слитк" in str(txt.lower())) or ("купить" in str(txt.lower())) or ("приобре" in str(txt.lower())) or ("инвестици" in str(txt.lower())) or ("инвест" in str(txt.lower())) or ("инвести" in str(txt.lower())) or ("инвестиц" in str(txt.lower())) or ("нет" in str(txt.lower())) or ("в наличии" in str(txt.lower())) or (("качество" in str(txt.lower())) and ("обслуживан" in str(txt.lower()))) or ("метал" in str(txt.lower())) or ("драг" in str(txt.lower())):
        date = dom2.find('span', {'class': 'dtreviewed'}).getText().replace('\t','').replace('\n','')
        title = dom2.find('h1').getText().replace('\t', '').replace('\n', '').replace('\t','')            
        new_row = {'Сайт': 'www.otzyvru.com', 'Населенный пункт': city, 'Дата': date, 'Заголовок': title, 'Основной текст жалобы': txt}
        df6 = df6.append(new_row, ignore_index=True)
    df6.to_excel(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\сравни\otzyvru' + str(i) + '.xlsx', index=False)

# %%
#нет в наличии слитков, нет слитков, нет в наличии слитк, нет слитк, нет слиток, слиток, слитков, золот, драг, метал, слитк, купить

# %%
import glob

# %%
res = pd.DataFrame()
for file in glob.glob(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\*'):
    print(file)
    df = pd.read_excel(file)
    res = res.append(df)

# %%
res

# %%
res.to_excel(r'C:\Users\19586955\Documents\Morzavchenkova\python\parse\result_file.xlsx', index=False)
